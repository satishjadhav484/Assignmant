# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.arange(0,20,2))

# %%
plt.plot([2,4,6,8,10,9,2,4,5])

# %%
plt.plot(np.random.randn(50),color='Purple')

# %%
plt.hist(np.random.randn(100),bins=20)
# Out:
# (array([ 1.,  4.,  5.,  3.,  6.,  7.,  8.,  7., 10., 10.,  5.,  8., 10.,
#          5.,  5.,  4.,  1.,  0.,  0.,  1.]),
#  array([-2.365202  , -2.09830482, -1.83140764, -1.56451046, -1.29761328,
#         -1.0307161 , -0.76381891, -0.49692173, -0.23002455,  0.03687263,
#          0.30376981,  0.57066699,  0.83756417,  1.10446135,  1.37135853,
#          1.63825572,  1.9051529 ,  2.17205008,  2.43894726,  2.70584444,
#          2.97274162]),
#  <BarContainer object of 20 artists>)

# %%
plt.scatter(np.arange(50),np.random.randn(50))

# %%
plt.pie(np.random.rand(5))
# Out:
# ([<matplotlib.patches.Wedge at 0x15ec33cc4c0>,
# ...
#  [Text(0.5666304376460244, 0.9428308157527919, ''),
#   Text(-1.0997892893322758, 0.021529493027192526, ''),
#   Text(0.30464084322278384, -1.0569739621393288, ''),
#   Text(1.066872826805508, -0.26792232348952294, ''),
#   Text(1.099985791606903, -0.005590908954321878, '')])

# %%
plt.plot(np.random.randn(50),color='Purple',linestyle='-.')

# %%
plt.bar([1,2,3,4,5],[10,20,45,30,20],color='Grey')

plt.title('My First Graph')
plt.xlabel("Satish")
plt.ylabel("Jadhav")
# Out:
# Text(0, 0.5, 'Jadhav')

# %%
#plt.get_cmap('plasma')
ax=plt.pie([10,25,25,45],labels=['a','b','c','d'],autopct='%1i%%')

# %%
plt.step([1,2,3,4],[10,20,30,10])

# %%
fig,p=plt.subplots(2,2)

p[0][0].plot(np.arange(50))
p[0][1].pie([10,25,25,45],labels=['a','b','c','d'])
p[1][0].bar([1,2,3,4,5],[10,20,45,30,20],color='Grey')
p[1][1].plot([2,4,6,8,10,9,2,4,5])

# %%
# we will cover seaborn and you will forget it
#plotly is also there 
#plotly is also availabel in R and Jully
# dash is also good to build (graph of) chess
