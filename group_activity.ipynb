# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/hp/Downloads/usgs_earthquakes_2014.csv")

# %%
df.head(2)
# Out:
#                       time  latitude  longitude  depth   mag magType  nst  \
# 0  2014-01-31 23:53:37.000   60.2520  -152.7081   90.2  1.10      ml  NaN
# 1  2014-01-31 23:48:35.452   37.0703  -115.1309    0.0  1.33      ml  4.0
#
#       gap   dmin     rms net          id                   updated  \
# 0     NaN    NaN  0.2900  ak  ak11155107  2014-02-05T19:34:41.515Z
# 1  171.43  0.342  0.0247  nn  nn00436847  2014-02-01T01:35:09.000Z
#
#                                place        type
# 0  26km S of Redoubt Volcano, Alaska  earthquake
# 1            32km S of Alamo, Nevada  earthquake

# %%
df=df.rename(columns={"time":"dates"})
df.head(2)
# Out:
#                      dates  latitude  longitude  depth   mag magType  nst  \
# 0  2014-01-31 23:53:37.000   60.2520  -152.7081   90.2  1.10      ml  NaN
# 1  2014-01-31 23:48:35.452   37.0703  -115.1309    0.0  1.33      ml  4.0
#
#       gap   dmin     rms net          id                   updated  \
# 0     NaN    NaN  0.2900  ak  ak11155107  2014-02-05T19:34:41.515Z
# 1  171.43  0.342  0.0247  nn  nn00436847  2014-02-01T01:35:09.000Z
#
#                                place        type
# 0  26km S of Redoubt Volcano, Alaska  earthquake
# 1            32km S of Alamo, Nevada  earthquake

# %%
df=df.set_index("id")
df.head(2)
# Out:
#                               dates  latitude  longitude  depth   mag magType  \
# id
# ak11155107  2014-01-31 23:53:37.000   60.2520  -152.7081   90.2  1.10      ml
# nn00436847  2014-01-31 23:48:35.452   37.0703  -115.1309    0.0  1.33      ml
#
#             nst     gap   dmin     rms net                   updated  \
# id
# ak11155107  NaN     NaN    NaN  0.2900  ak  2014-02-05T19:34:41.515Z
# nn00436847  4.0  171.43  0.342  0.0247  nn  2014-02-01T01:35:09.000Z
#
#                                         place        type
# id
# ak11155107  26km S of Redoubt Volcano, Alaska  earthquake
# nn00436847            32km S of Alamo, Nevada  earthquake

# %%
df.describe()   # for all columns
# Out:
#             latitude      longitude          depth            mag  \
# count  120108.000000  120108.000000  120107.000000  120065.000000
# mean       38.399579     -99.961402      28.375029       1.793958
# std        21.938258      82.996858      62.215416       1.343466
# min       -73.462000    -179.998900      -9.900000      -0.970000
# 25%        34.228917    -147.742025       4.100000       0.820000
# 50%        38.805300    -120.832000       9.200000       1.400000
# 75%        53.889500    -116.068100      22.880000       2.400000
# max        86.651400     179.998000     697.360000       8.200000
#
#                 nst           gap          dmin            rms
# count  59688.000000  94935.000000  85682.000000  119716.000000
# mean      17.878284    124.048978      0.893198       0.358174
# std       14.911369     68.518595      2.903966       0.364046
# min        0.000000      9.000000      0.000000       0.000000
# ...

# %%
df['depth'].describe()  # summary stat for perticular 
                        #column only
# Out:
# count    120107.000000
# mean         28.375029
# std          62.215416
# min          -9.900000
# 25%           4.100000
# 50%           9.200000
# 75%          22.880000
# max         697.360000
# Name: depth, dtype: float64

# %%
df1=df.sort_values(by="mag",ascending=False)
df1.head(20)
# Out:
#                               dates  latitude  longitude   depth  mag magType  \
# id
# usc000nzvd  2014-04-01 23:46:47.260  -19.6097   -70.7691   25.00  8.2     mww
# usc000rki5  2014-06-23 20:53:09.700   51.8486   178.7352  109.00  7.9     mww
# usc000p27i  2014-04-03 02:43:13.110  -20.5709   -70.4931   22.40  7.7     mww
# usc000phx5  2014-04-12 20:14:39.300  -11.2701   162.1481   22.56  7.6     mww
# usb000pr89  2014-04-19 13:28:00.810   -6.7547   155.0241   43.37  7.5     mww
# usc000piqj  2014-04-13 12:36:19.230  -11.4633   162.0511   39.00  7.4     mww
# usb000slwn  2014-10-14 03:51:34.460   12.5262   -88.1225   40.00  7.3     mww
# usb000pq41  2014-04-18 14:27:24.920   17.3970  -100.9723   24.00  7.2     mww
# usc000pft9  2014-04-11 07:07:23.130   -6.5858   155.0485   60.53  7.1     mww
# usc000sxh8  2014-11-15 02:31:41.720    1.8929   126.5217   45.00  7.1     mww
# usc000stdc  2014-11-01 18:57:22.380  -19.6903  -177.7587  434.00  7.1     mww
# ...

# %%
df.place.str.rsplit(",",expand=True)
# Out:
#                                     0            1     2     3     4
# id
# ak11155107  26km S of Redoubt Volcano       Alaska  None  None  None
# nn00436847            32km S of Alamo       Nevada  None  None  None
# ak11151142   12km NNW of North Nenana       Alaska  None  None  None
# ak11151135         22km S of Cantwell       Alaska  None  None  None
# ci37171541       10km WNW of Progreso       Mexico  None  None  None
# ...                               ...          ...   ...   ...   ...
# ak11453391          29km SW of Valdez       Alaska  None  None  None
# ak11453395   102km SSE of Old Iliamna       Alaska  None  None  None
# nc72358451            9km WNW of Cobb   California  None  None  None
# ak11453390           57km NW of Ester       Alaska  None  None  None
# ak11453389        78km WSW of Cordova       Alaska  None  None  None
#
# [120108 rows x 5 columns]

# %%
df[['place1','country','a1','a2','a3']]=df.place.str.split(", ",expand=True)

df.head(3)
# Out:
#                               dates  latitude  longitude  depth   mag magType  \
# id
# ak11155107  2014-01-31 23:53:37.000   60.2520  -152.7081   90.2  1.10      ml
# nn00436847  2014-01-31 23:48:35.452   37.0703  -115.1309    0.0  1.33      ml
# ak11151142  2014-01-31 23:47:24.000   64.6717  -149.2528    7.1  1.30      ml
#
#             nst     gap   dmin     rms net                   updated  \
# id
# ak11155107  NaN     NaN    NaN  0.2900  ak  2014-02-05T19:34:41.515Z
# nn00436847  4.0  171.43  0.342  0.0247  nn  2014-02-01T01:35:09.000Z
# ak11151142  NaN     NaN    NaN  1.0000  ak  2014-02-01T00:03:53.010Z
#
#                                         place        type  \
# id
# ak11155107  26km S of Redoubt Volcano, Alaska  earthquake
# nn00436847            32km S of Alamo, Nevada  earthquake
# ak11151142   12km NNW of North Nenana, Alaska  earthquake
#
#                                place1 country    a1    a2    a3
# id
# ...

# %%
df3=df["country"].value_counts()
df3.head(10)                      # top 10 countries
# Out:
# California     44451
# Alaska         33589
# Oregon          3195
# Nevada          2858
# Washington      2784
# Hawaii          2564
# Puerto Rico     2284
# Indonesia       2120
# Oklahoma        1992
# Montana         1991
# Name: country, dtype: int64
